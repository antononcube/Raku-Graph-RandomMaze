# %% [markdown]
# # Raku Graph::RandomMaze

# %% [markdown]
# Raku package for random maze making using graphs.

# %% [markdown]
# The package provides the function `random-maze` the implementation of which is explained in [AA1].

# %% [markdown]
# **Remark:** Since the package "Graph", [AAp1], is used for the implementation the package name is
# "Graph::RandomMaze".

# %% [markdown]
# ---
#
# ## Setup

# %%
use Graph::RandomMaze;

# %%
sink my $engine = 'neato';

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Rectangular maze

# %%
my %rect = random-maze(rows => 8, columns => 16, type => 'rectangular');

deduce-type(%rect);
# Out:
# Struct([dimensions, end, paths, solution, start, type, walls], [Array, Str, Graph, Array, Str, Str, Graph])

# %% [markdown]
# The returned hash contains:
#
# - Carved wall graph (`walls`),
# - Spanning tree used for carving (`paths`),
# - Shortest-path solution (`solution`),
# - Bookkeeping keys (`shape`, `dimensions`, `start`, `end`)

# %%
#%html
my %opts = engine => 'neato', :8size, vertex-shape => 'point', edge-thickness => 12;
%rect<walls>.dot(|%opts):svg;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="277pt"
#  viewBox="0.00 0.00 576.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.519106 0.519106) rotate(0) translate(4 529.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-529.6 1105.6,-529.6 1105.6,4 -4,4"/>
# <!-- w7_7 -->
# <g id="node1" class="node">
# <title>w7_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_8 -->
# <g id="node119" class="node">
# <title>w7_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_7&#45;&#45;w7_8 -->
# <g id="edge60" class="edge">
# <title>w7_7&#45;&#45;w7_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M526.05,-514.8C539.66,-514.8 562.4,-514.8 575.86,-514.8"/>
# </g>
# <!-- w7_10 -->
# <g id="node2" class="node">
# <title>w7_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_9 -->
# <g id="node39" class="node">
# <title>w7_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_10&#45;&#45;w7_9 -->
# <g id="edge5" class="edge">
# <title>w7_10&#45;&#45;w7_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M719.55,-514.8C705.94,-514.8 683.2,-514.8 669.74,-514.8"/>
# </g>
# <!-- w7_11 -->
# <g id="node66" class="node">
# <title>w7_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_10&#45;&#45;w7_11 -->
# <g id="edge29" class="edge">
# <title>w7_10&#45;&#45;w7_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M742.05,-514.8C755.66,-514.8 778.4,-514.8 791.86,-514.8"/>
# </g>
# <!-- w0_11 -->
# <g id="node3" class="node">
# <title>w0_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_12 -->
# <g id="node65" class="node">
# <title>w0_12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="874.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_11&#45;&#45;w0_12 -->
# <g id="edge73" class="edge">
# <title>w0_11&#45;&#45;w0_12</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M814.05,-10.8C827.66,-10.8 850.4,-10.8 863.86,-10.8"/>
# </g>
# <!-- w0_7 -->
# <g id="node4" class="node">
# <title>w0_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_8 -->
# <g id="node19" class="node">
# <title>w0_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_7&#45;&#45;w0_8 -->
# <g id="edge13" class="edge">
# <title>w0_7&#45;&#45;w0_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M526.05,-10.8C539.66,-10.8 562.4,-10.8 575.86,-10.8"/>
# </g>
# <!-- w1_7 -->
# <g id="node117" class="node">
# <title>w1_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_7&#45;&#45;w1_7 -->
# <g id="edge11" class="edge">
# <title>w0_7&#45;&#45;w1_7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M514.8,-22.05C514.8,-35.66 514.8,-58.4 514.8,-71.86"/>
# </g>
# <!-- w5_7 -->
# <g id="node5" class="node">
# <title>w5_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_7 -->
# <g id="node40" class="node">
# <title>w6_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_7&#45;&#45;w6_7 -->
# <g id="edge109" class="edge">
# <title>w5_7&#45;&#45;w6_7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M514.8,-382.05C514.8,-395.66 514.8,-418.4 514.8,-431.86"/>
# </g>
# <!-- w6_9 -->
# <g id="node6" class="node">
# <title>w6_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_1 -->
# <g id="node7" class="node">
# <title>w4_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_2 -->
# <g id="node75" class="node">
# <title>w4_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_1&#45;&#45;w4_2 -->
# <g id="edge104" class="edge">
# <title>w4_1&#45;&#45;w4_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M94.05,-298.8C107.66,-298.8 130.4,-298.8 143.86,-298.8"/>
# </g>
# <!-- w6_0 -->
# <g id="node8" class="node">
# <title>w6_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_0 -->
# <g id="node20" class="node">
# <title>w7_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_0&#45;&#45;w7_0 -->
# <g id="edge107" class="edge">
# <title>w6_0&#45;&#45;w7_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M10.8,-454.05C10.8,-467.66 10.8,-490.4 10.8,-503.86"/>
# </g>
# <!-- w6_14 -->
# <g id="node9" class="node">
# <title>w6_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_9 -->
# <g id="node10" class="node">
# <title>w4_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_9 -->
# <g id="node73" class="node">
# <title>w5_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_9&#45;&#45;w5_9 -->
# <g id="edge71" class="edge">
# <title>w4_9&#45;&#45;w5_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M658.8,-310.05C658.8,-323.66 658.8,-346.4 658.8,-359.86"/>
# </g>
# <!-- w3_1 -->
# <g id="node11" class="node">
# <title>w3_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_5 -->
# <g id="node12" class="node">
# <title>w1_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_5 -->
# <g id="node122" class="node">
# <title>w2_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_5&#45;&#45;w2_5 -->
# <g id="edge20" class="edge">
# <title>w1_5&#45;&#45;w2_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M370.8,-94.05C370.8,-107.66 370.8,-130.4 370.8,-143.86"/>
# </g>
# <!-- w4_8 -->
# <g id="node13" class="node">
# <title>w4_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_8 -->
# <g id="node31" class="node">
# <title>w5_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_8&#45;&#45;w5_8 -->
# <g id="edge32" class="edge">
# <title>w4_8&#45;&#45;w5_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M586.8,-310.05C586.8,-323.66 586.8,-346.4 586.8,-359.86"/>
# </g>
# <!-- w3_7 -->
# <g id="node14" class="node">
# <title>w3_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2 -->
# <g id="node15" class="node">
# <title>w3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_3 -->
# <g id="node58" class="node">
# <title>w3_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2&#45;&#45;w3_3 -->
# <g id="edge28" class="edge">
# <title>w3_2&#45;&#45;w3_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M166.05,-226.8C179.66,-226.8 202.4,-226.8 215.86,-226.8"/>
# </g>
# <!-- w3_2&#45;&#45;w4_2 -->
# <g id="edge27" class="edge">
# <title>w3_2&#45;&#45;w4_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M154.8,-238.05C154.8,-251.66 154.8,-274.4 154.8,-287.86"/>
# </g>
# <!-- w0_5 -->
# <g id="node16" class="node">
# <title>w0_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-10.8" rx="10.8" ry="10.8"/>

# %% [markdown]
# ![](./docs/rectangular-maze.svg)

# %%
#%html
my $gSolution = %rect<paths>.subgraph(%rect<solution>);
my $g = %rect<walls>.union($gSolution);
my $highlight = $gSolution;
$g.dot(
    :$highlight,
    :$engine, 
    :8size, 
    vertex-shape => 'point', 
    edge-thickness => 12
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="277pt"
#  viewBox="0.00 0.00 576.00 277.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.519106 0.519106) rotate(0) translate(4 529.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-529.6 1105.6,-529.6 1105.6,4 -4,4"/>
# <!-- w4_7 -->
# <g id="node1" class="node">
# <title>w4_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_7 -->
# <g id="node46" class="node">
# <title>w5_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_7&#45;&#45;w5_7 -->
# <g id="edge45" class="edge">
# <title>w4_7&#45;&#45;w5_7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M514.8,-310.05C514.8,-323.66 514.8,-346.4 514.8,-359.86"/>
# </g>
# <!-- w4_8 -->
# <g id="node89" class="node">
# <title>w4_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_7&#45;&#45;w4_8 -->
# <g id="edge44" class="edge">
# <title>w4_7&#45;&#45;w4_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M526.05,-298.8C539.66,-298.8 562.4,-298.8 575.86,-298.8"/>
# </g>
# <!-- 0_0 -->
# <g id="node2" class="node">
# <title>0_0</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="46.8" cy="-46.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 0_1 -->
# <g id="node88" class="node">
# <title>0_1</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="118.8" cy="-46.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 0_0&#45;&#45;0_1 -->
# <g id="edge139" class="edge">
# <title>0_0&#45;&#45;0_1</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M58.05,-46.8C71.66,-46.8 94.4,-46.8 107.86,-46.8"/>
# </g>
# <!-- 1_7 -->
# <g id="node3" class="node">
# <title>1_7</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="550.8" cy="-118.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 1_8 -->
# <g id="node123" class="node">
# <title>1_8</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="622.8" cy="-118.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 1_7&#45;&#45;1_8 -->
# <g id="edge135" class="edge">
# <title>1_7&#45;&#45;1_8</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M562.05,-118.8C575.66,-118.8 598.4,-118.8 611.86,-118.8"/>
# </g>
# <!-- w4_1 -->
# <g id="node4" class="node">
# <title>w4_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_2 -->
# <g id="node57" class="node">
# <title>w4_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_1&#45;&#45;w4_2 -->
# <g id="edge49" class="edge">
# <title>w4_1&#45;&#45;w4_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M94.05,-298.8C107.66,-298.8 130.4,-298.8 143.86,-298.8"/>
# </g>
# <!-- w6_8 -->
# <g id="node5" class="node">
# <title>w6_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_9 -->
# <g id="node29" class="node">
# <title>w6_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_8&#45;&#45;w6_9 -->
# <g id="edge88" class="edge">
# <title>w6_8&#45;&#45;w6_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M598.05,-442.8C611.66,-442.8 634.4,-442.8 647.86,-442.8"/>
# </g>
# <!-- w7_8 -->
# <g id="node39" class="node">
# <title>w7_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_8&#45;&#45;w7_8 -->
# <g id="edge123" class="edge">
# <title>w6_8&#45;&#45;w7_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M586.8,-454.05C586.8,-467.66 586.8,-490.4 586.8,-503.86"/>
# </g>
# <!-- w6_5 -->
# <g id="node6" class="node">
# <title>w6_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_5 -->
# <g id="node28" class="node">
# <title>w7_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_5&#45;&#45;w7_5 -->
# <g id="edge109" class="edge">
# <title>w6_5&#45;&#45;w7_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M370.8,-454.05C370.8,-467.66 370.8,-490.4 370.8,-503.86"/>
# </g>
# <!-- 2_10 -->
# <g id="node7" class="node">
# <title>2_10</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="766.8" cy="-190.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 2_9 -->
# <g id="node24" class="node">
# <title>2_9</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="694.8" cy="-190.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 2_10&#45;&#45;2_9 -->
# <g id="edge134" class="edge">
# <title>2_10&#45;&#45;2_9</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M755.55,-190.8C741.94,-190.8 719.2,-190.8 705.74,-190.8"/>
# </g>
# <!-- 3_10 -->
# <g id="node132" class="node">
# <title>3_10</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="766.8" cy="-262.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 2_10&#45;&#45;3_10 -->
# <g id="edge132" class="edge">
# <title>2_10&#45;&#45;3_10</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M766.8,-202.05C766.8,-215.66 766.8,-238.4 766.8,-251.86"/>
# </g>
# <!-- w3_3 -->
# <g id="node8" class="node">
# <title>w3_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_3 -->
# <g id="node14" class="node">
# <title>w4_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_3&#45;&#45;w4_3 -->
# <g id="edge73" class="edge">
# <title>w3_3&#45;&#45;w4_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-238.05C226.8,-251.66 226.8,-274.4 226.8,-287.86"/>
# </g>
# <!-- 5_10 -->
# <g id="node9" class="node">
# <title>5_10</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="766.8" cy="-406.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 6_10 -->
# <g id="node114" class="node">
# <title>6_10</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="766.8" cy="-478.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 5_10&#45;&#45;6_10 -->
# <g id="edge145" class="edge">
# <title>5_10&#45;&#45;6_10</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M766.8,-418.05C766.8,-431.66 766.8,-454.4 766.8,-467.86"/>
# </g>
# <!-- w3_9 -->
# <g id="node10" class="node">
# <title>w3_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_9 -->
# <g id="node55" class="node">
# <title>w4_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_9&#45;&#45;w4_9 -->
# <g id="edge23" class="edge">
# <title>w3_9&#45;&#45;w4_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M658.8,-238.05C658.8,-251.66 658.8,-274.4 658.8,-287.86"/>
# </g>
# <!-- w6_4 -->
# <g id="node11" class="node">
# <title>w6_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_4 -->
# <g id="node124" class="node">
# <title>w7_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_4&#45;&#45;w7_4 -->
# <g id="edge85" class="edge">
# <title>w6_4&#45;&#45;w7_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M298.8,-454.05C298.8,-467.66 298.8,-490.4 298.8,-503.86"/>
# </g>
# <!-- w0_15 -->
# <g id="node12" class="node">
# <title>w0_15</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1090.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_15 -->
# <g id="node31" class="node">
# <title>w1_15</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1090.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_15&#45;&#45;w1_15 -->
# <g id="edge7" class="edge">
# <title>w0_15&#45;&#45;w1_15</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1090.8,-22.05C1090.8,-35.66 1090.8,-58.4 1090.8,-71.86"/>
# </g>
# <!-- w7_3 -->
# <g id="node13" class="node">

# %% [markdown]
# ---
#
# ## Hexagonal maze

# %%
my %hex = random-maze(rows => 8, columns => 16, type => 'hexagonal');

deduce-type(%hex);
# Out:
# Struct([dimensions, end, paths, solution, start, type, walls], [Array, Str, Graph, Array, Str, Str, Graph])

# %%
#%html
%opts<edge-thickness> = 32;
%hex<walls>.dot(|%opts):svg;
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="215pt"
#  viewBox="0.00 0.00 576.00 215.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.117714 0.117714) rotate(0) translate(4 1825.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-1825.6 4889.2,-1825.6 4889.2,4 -4,4"/>
# <!-- w223 -->
# <g id="node1" class="node">
# <title>w223</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3377.91" cy="-1738.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w232 -->
# <g id="node79" class="node">
# <title>w232</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3502.61" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w223&#45;&#45;w232 -->
# <g id="edge187" class="edge">
# <title>w223&#45;&#45;w232</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3387.69,-1744.45C3411,-1757.91 3469.61,-1791.74 3492.87,-1805.18"/>
# </g>
# <!-- w243 -->
# <g id="node2" class="node">
# <title>w243</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3752.03" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w252 -->
# <g id="node11" class="node">
# <title>w252</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3876.74" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w243&#45;&#45;w252 -->
# <g id="edge7" class="edge">
# <title>w243&#45;&#45;w252</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3761.82,-232.45C3785.13,-245.91 3843.73,-279.74 3867,-293.18"/>
# </g>
# <!-- w274 -->
# <g id="node3" class="node">
# <title>w274</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4126.15" cy="-1306.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w281 -->
# <g id="node225" class="node">
# <title>w281</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4250.86" cy="-1378.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w274&#45;&#45;w281 -->
# <g id="edge268" class="edge">
# <title>w274&#45;&#45;w281</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4135.94,-1312.45C4159.25,-1325.91 4217.85,-1359.74 4241.12,-1373.18"/>
# </g>
# <!-- w285 -->
# <g id="node4" class="node">
# <title>w285</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4375.57" cy="-874.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w290 -->
# <g id="node134" class="node">
# <title>w290</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4500.28" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w285&#45;&#45;w290 -->
# <g id="edge128" class="edge">
# <title>w285&#45;&#45;w290</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4385.35,-880.45C4408.67,-893.91 4467.27,-927.74 4490.54,-941.18"/>
# </g>
# <!-- w270 -->
# <g id="node5" class="node">
# <title>w270</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4126.15" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w277 -->
# <g id="node83" class="node">
# <title>w277</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4250.86" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w270&#45;&#45;w277 -->
# <g id="edge87" class="edge">
# <title>w270&#45;&#45;w277</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4135.94,-448.45C4159.25,-461.91 4217.85,-495.74 4241.12,-509.18"/>
# </g>
# <!-- w279 -->
# <g id="node6" class="node">
# <title>w279</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4250.86" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w280 -->
# <g id="node301" class="node">
# <title>w280</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4250.86" cy="-1090.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w279&#45;&#45;w280 -->
# <g id="edge25" class="edge">
# <title>w279&#45;&#45;w280</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4250.86,-958.1C4250.86,-985.02 4250.86,-1052.69 4250.86,-1079.55"/>
# </g>
# <!-- w259 -->
# <g id="node7" class="node">
# <title>w259</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3876.74" cy="-1738.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w268 -->
# <g id="node121" class="node">
# <title>w268</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4001.44" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w259&#45;&#45;w268 -->
# <g id="edge127" class="edge">
# <title>w259&#45;&#45;w268</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3886.52,-1744.45C3909.84,-1757.91 3968.44,-1791.74 3991.7,-1805.18"/>
# </g>
# <!-- w120 -->
# <g id="node8" class="node">
# <title>w120</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2006.12" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w121 -->
# <g id="node261" class="node">
# <title>w121</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2006.12" cy="-1090.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w120&#45;&#45;w121 -->
# <g id="edge15" class="edge">
# <title>w120&#45;&#45;w121</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2006.12,-958.1C2006.12,-985.02 2006.12,-1052.69 2006.12,-1079.55"/>
# </g>
# <!-- w233 -->
# <g id="node9" class="node">
# <title>w233</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3627.32" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w242 -->
# <g id="node233" class="node">
# <title>w242</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3752.03" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w233&#45;&#45;w242 -->
# <g id="edge287" class="edge">
# <title>w233&#45;&#45;w242</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3637.11,-16.45C3660.42,-29.91 3719.02,-63.74 3742.29,-77.18"/>
# </g>
# <!-- w236 -->
# <g id="node10" class="node">
# <title>w236</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3627.32" cy="-730.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w245 -->
# <g id="node111" class="node">
# <title>w245</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3752.03" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w236&#45;&#45;w245 -->
# <g id="edge82" class="edge">
# <title>w236&#45;&#45;w245</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3637.11,-725.15C3660.42,-711.69 3719.02,-677.86 3742.29,-664.42"/>
# </g>
# <!-- w237 -->
# <g id="node222" class="node">
# <title>w237</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3627.32" cy="-874.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w236&#45;&#45;w237 -->
# <g id="edge83" class="edge">
# <title>w236&#45;&#45;w237</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3627.32,-742.1C3627.32,-769.02 3627.32,-836.69 3627.32,-863.55"/>
# </g>
# <!-- w253 -->
# <g id="node18" class="node">
# <title>w253</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3876.74" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w252&#45;&#45;w253 -->
# <g id="edge146" class="edge">
# <title>w252&#45;&#45;w253</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3876.74,-310.1C3876.74,-337.02 3876.74,-404.69 3876.74,-431.55"/>
# </g>
# <!-- w42 -->
# <g id="node12" class="node">
# <title>w42</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="883.75" cy="-1594.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w43 -->
# <g id="node188" class="node">
# <title>w43</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="883.75" cy="-1738.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w42&#45;&#45;w43 -->
# <g id="edge197" class="edge">
# <title>w42&#45;&#45;w43</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M883.75,-1606.1C883.75,-1633.02 883.75,-1700.69 883.75,-1727.55"/>
# </g>
# <!-- w51 -->
# <g id="node220" class="node">
# <title>w51</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1008.46" cy="-1522.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w42&#45;&#45;w51 -->
# <g id="edge207" class="edge">
# <title>w42&#45;&#45;w51</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M893.54,-1589.15C916.85,-1575.69 975.45,-1541.86 998.72,-1528.42"/>
# </g>
# <!-- w66 -->
# <g id="node13" class="node">
# <title>w66</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1257.88" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w67 -->
# <g id="node240" class="node">
# <title>w67</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1257.88" cy="-1090.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w66&#45;&#45;w67 -->
# <g id="edge182" class="edge">
# <title>w66&#45;&#45;w67</title>
# <path fill="none" str

# %% [markdown]
# ![](./docs/hexagonal-maze.svg)

# %%
#%html
my $gSolution = %hex<paths>.subgraph(%hex<solution>);
my $g = %hex<walls>.union($gSolution);
my $highlight = $gSolution;
$g.dot(
    :$highlight,
    :$engine, 
    :8size, 
    vertex-shape => 'point', 
    edge-thickness => 32
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="215pt"
#  viewBox="0.00 0.00 576.00 215.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.117714 0.117714) rotate(0) translate(4 1825.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-1825.6 4889.2,-1825.6 4889.2,4 -4,4"/>
# <!-- w237 -->
# <g id="node1" class="node">
# <title>w237</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3627.32" cy="-874.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w197 -->
# <g id="node2" class="node">
# <title>w197</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3128.49" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w206 -->
# <g id="node8" class="node">
# <title>w206</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3253.2" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w197&#45;&#45;w206 -->
# <g id="edge233" class="edge">
# <title>w197&#45;&#45;w206</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3138.28,-16.45C3161.59,-29.91 3220.19,-63.74 3243.46,-77.18"/>
# </g>
# <!-- w235 -->
# <g id="node3" class="node">
# <title>w235</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3627.32" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w244 -->
# <g id="node176" class="node">
# <title>w244</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3752.03" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w235&#45;&#45;w244 -->
# <g id="edge106" class="edge">
# <title>w235&#45;&#45;w244</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3637.11,-448.45C3660.42,-461.91 3719.02,-495.74 3742.29,-509.18"/>
# </g>
# <!-- w137 -->
# <g id="node4" class="node">
# <title>w137</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2255.54" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w15 -->
# <g id="node5" class="node">
# <title>w15</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="509.63" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w21 -->
# <g id="node164" class="node">
# <title>w21</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="634.34" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w15&#45;&#45;w21 -->
# <g id="edge296" class="edge">
# <title>w15&#45;&#45;w21</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M519.42,-232.45C542.73,-245.91 601.33,-279.74 624.6,-293.18"/>
# </g>
# <!-- w68 -->
# <g id="node6" class="node">
# <title>w68</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1257.88" cy="-1378.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w69 -->
# <g id="node50" class="node">
# <title>w69</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1257.88" cy="-1522.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w68&#45;&#45;w69 -->
# <g id="edge27" class="edge">
# <title>w68&#45;&#45;w69</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1257.88,-1390.1C1257.88,-1417.02 1257.88,-1484.69 1257.88,-1511.55"/>
# </g>
# <!-- w100 -->
# <g id="node7" class="node">
# <title>w100</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1756.71" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w101 -->
# <g id="node29" class="node">
# <title>w101</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1756.71" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w100&#45;&#45;w101 -->
# <g id="edge221" class="edge">
# <title>w100&#45;&#45;w101</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1756.71,-526.1C1756.71,-553.02 1756.71,-620.69 1756.71,-647.55"/>
# </g>
# <!-- w109 -->
# <g id="node158" class="node">
# <title>w109</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1881.41" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w100&#45;&#45;w109 -->
# <g id="edge299" class="edge">
# <title>w100&#45;&#45;w109</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1766.49,-509.15C1789.8,-495.69 1848.41,-461.86 1871.67,-448.42"/>
# </g>
# <!-- w215 -->
# <g id="node36" class="node">
# <title>w215</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3377.91" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w206&#45;&#45;w215 -->
# <g id="edge8" class="edge">
# <title>w206&#45;&#45;w215</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3262.98,-77.15C3286.3,-63.69 3344.9,-29.86 3368.17,-16.42"/>
# </g>
# <!-- w207 -->
# <g id="node280" class="node">
# <title>w207</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3253.2" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w206&#45;&#45;w207 -->
# <g id="edge203" class="edge">
# <title>w206&#45;&#45;w207</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3253.2,-94.1C3253.2,-121.02 3253.2,-188.69 3253.2,-215.55"/>
# </g>
# <!-- w44 -->
# <g id="node9" class="node">
# <title>w44</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1008.46" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w53 -->
# <g id="node41" class="node">
# <title>w53</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1133.17" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w44&#45;&#45;w53 -->
# <g id="edge89" class="edge">
# <title>w44&#45;&#45;w53</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1018.25,-77.15C1041.56,-63.69 1100.16,-29.86 1123.43,-16.42"/>
# </g>
# <!-- w45 -->
# <g id="node274" class="node">
# <title>w45</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1008.46" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w44&#45;&#45;w45 -->
# <g id="edge88" class="edge">
# <title>w44&#45;&#45;w45</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1008.46,-94.1C1008.46,-121.02 1008.46,-188.69 1008.46,-215.55"/>
# </g>
# <!-- 49 -->
# <g id="node10" class="node">
# <title>49</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="2006.12" cy="-802.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 57 -->
# <g id="node32" class="node">
# <title>57</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="2255.54" cy="-802.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 49&#45;&#45;57 -->
# <g id="edge327" class="edge">
# <title>49&#45;&#45;57</title>
# <path fill="none" stroke="DarkOrange" stroke-width="32" d="M2017.16,-802.8C2058.36,-802.8 2202.89,-802.8 2244.34,-802.8"/>
# </g>
# <!-- w118 -->
# <g id="node11" class="node">
# <title>w118</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2006.12" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w119 -->
# <g id="node38" class="node">
# <title>w119</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2006.12" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w118&#45;&#45;w119 -->
# <g id="edge201" class="edge">
# <title>w118&#45;&#45;w119</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2006.12,-526.1C2006.12,-553.02 2006.12,-620.69 2006.12,-647.55"/>
# </g>
# <!-- 79 -->
# <g id="node12" class="node">
# <title>79</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="2879.08" cy="-1450.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 46 -->
# <g id="node13" class="node">
# <title>46</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="1881.41" cy="-1018.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 46&#45;&#45;49 -->
# <g id="edge310" class="edge">
# <title>46&#45;&#45;49</title>
# <path fill="none" stroke="DarkOrange" stroke-width="32" d="M1886.93,-1009.24C1907.58,-973.48 1980.13,-847.82 2000.67,-812.25"/>
# </g>
# <!-- w179 -->
# <g id="node14" class="node">
# <title>w179</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2879.08" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w188 -->
# <g id="node175" class="node">
# <title>w188</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3003.78" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w179&#45;&#45;w188 -->
# <g id="edge143" class="edge">
# <title>w179&#45;&#45;w188</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2888.86,-16.45C2912.17,-29.91 2970.78,-63.74 2994.04,-77.18"/>
# </g>
# <!-- w71 -->
# <g id="node15" class="node">
# <title>w71</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1382.58" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w80 -->
# <g id="node171" class="node">
# <title>w80</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1507.29" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w71&#45;&#45;w80 -->
# <g

# %%
#spurt('hexagonal-maze.svg', %hex<walls>.dot(|%opts):svg)
# Out:
# ()

# %% [markdown]
# ---

# %% [markdown]
# ## References

# %% [markdown]
# [AA1] Anton Antonov,
# ["Day 24 – Maze Making Using Graphs"](https://raku-advent.blog/2025/12/24/day-24-maze-making-using-graphs/),
# (2025),
# [Raku Advent Calendar at WordPress](https://raku-advent.blog/).

# %% [markdown]
# [AAp1] Anton Antonov,
# [Graph, Raku package](https://github.com/antononcube/Raku-Graph),
# (2024-2025),
# [GitHub/antononcube](https://github.com/antononcube).

# %% [markdown]
# # Random labyrinths

# %% [markdown]
# Generate random labyrinths

# %% [markdown]
# ----
#
# ## Documentation

# %% [markdown]
# ### Usage

# %% [markdown]
# `random-maze(n)`
#     generate a random labyrinth based on $n \times n$ grid graph.
#
# `random-maze([n, m])`
# generate a random labyrinth based on a grid graph with $n$ rows and $m$ columns.
#
# `&random-labyrinth` is a synonym of `&random-maze`.

# %% [markdown]
# ### Details & Options
#
# - The sub `random-maze` generates labyrinths based on regular rectangular grid graphs or hexagonal grid graphs.
# - By default, are generated random labyrinths based on rectangular grid graphs.
# - The labyrinth elements can be obtained by using the second argument (the "properties argument.")
# - The labyrinth elements are: walls, paths (pathways), solution, start, and end.

# %% [markdown]
# ---
#
# ## Setup

# %%
use Graph::RandomMaze;
use Data::Generators;
use JavaScript::D3;

sink my $engine = 'neato';
sink my $vertex-shape = 'point';
sink my $graph-size = 8;
sink my %opts = :$engine, :8size, :$vertex-shape, edge-thickness => 12;
sink my %hex-opts = :$engine, :8size, :$vertex-shape, vertex-width => 0.8, vertex-height => 0.8, edge-thickness => 32;

sink my $background = '#1F1F1F';

# %%
my sub display-maze(%maze, *%opts) {
    my $gSolution = %maze<paths>.subgraph(%maze<solution>);
    my $g = %maze<walls>.union($gSolution);
    my $highlight = $gSolution;
    $g.dot(:$highlight, |%opts):svg
}
# Out:
# &display-maze

# %%
#% javascript
require.config({
     paths: {
     d3: 'https://d3js.org/d3.v7.min'
}});

require(['d3'], function(d3) {
     console.log(d3);
});

# %% [markdown]
# ----
#
# ## Examples

# %% [markdown]
# ### Basic Examples

# %% [markdown]
# Make a random rectangular grid labyrinth:

# %%
#%html
random-maze(:10rows, :20columns).dot(|%opts):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="279pt"
#  viewBox="0.00 0.00 576.00 279.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.412135 0.412135) rotate(0) translate(4 673.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-673.6 1393.6,-673.6 1393.6,4 -4,4"/>
# <!-- w8_9 -->
# <g id="node1" class="node">
# <title>w8_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-586.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_19 -->
# <g id="node2" class="node">
# <title>w5_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_19 -->
# <g id="node83" class="node">
# <title>w6_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_19&#45;&#45;w6_19 -->
# <g id="edge153" class="edge">
# <title>w5_19&#45;&#45;w6_19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1378.8,-382.05C1378.8,-395.66 1378.8,-418.4 1378.8,-431.86"/>
# </g>
# <!-- w6_6 -->
# <g id="node3" class="node">
# <title>w6_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_6 -->
# <g id="node120" class="node">
# <title>w7_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_6&#45;&#45;w7_6 -->
# <g id="edge32" class="edge">
# <title>w6_6&#45;&#45;w7_6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M442.8,-454.05C442.8,-467.66 442.8,-490.4 442.8,-503.86"/>
# </g>
# <!-- w1_3 -->
# <g id="node4" class="node">
# <title>w1_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_3 -->
# <g id="node186" class="node">
# <title>w2_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_3&#45;&#45;w2_3 -->
# <g id="edge93" class="edge">
# <title>w1_3&#45;&#45;w2_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-94.05C226.8,-107.66 226.8,-130.4 226.8,-143.86"/>
# </g>
# <!-- w0_10 -->
# <g id="node5" class="node">
# <title>w0_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_9 -->
# <g id="node100" class="node">
# <title>w0_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10&#45;&#45;w0_9 -->
# <g id="edge99" class="edge">
# <title>w0_10&#45;&#45;w0_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M719.55,-10.8C705.94,-10.8 683.2,-10.8 669.74,-10.8"/>
# </g>
# <!-- w0_11 -->
# <g id="node103" class="node">
# <title>w0_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10&#45;&#45;w0_11 -->
# <g id="edge193" class="edge">
# <title>w0_10&#45;&#45;w0_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M742.05,-10.8C755.66,-10.8 778.4,-10.8 791.86,-10.8"/>
# </g>
# <!-- w1_19 -->
# <g id="node6" class="node">
# <title>w1_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_19 -->
# <g id="node170" class="node">
# <title>w2_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_19&#45;&#45;w2_19 -->
# <g id="edge105" class="edge">
# <title>w1_19&#45;&#45;w2_19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1378.8,-94.05C1378.8,-107.66 1378.8,-130.4 1378.8,-143.86"/>
# </g>
# <!-- w0_3 -->
# <g id="node7" class="node">
# <title>w0_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_4 -->
# <g id="node94" class="node">
# <title>w0_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_3&#45;&#45;w0_4 -->
# <g id="edge168" class="edge">
# <title>w0_3&#45;&#45;w0_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M238.05,-10.8C251.66,-10.8 274.4,-10.8 287.86,-10.8"/>
# </g>
# <!-- w9_10 -->
# <g id="node8" class="node">
# <title>w9_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_11 -->
# <g id="node107" class="node">
# <title>w9_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_10&#45;&#45;w9_11 -->
# <g id="edge130" class="edge">
# <title>w9_10&#45;&#45;w9_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M742.05,-658.8C755.66,-658.8 778.4,-658.8 791.86,-658.8"/>
# </g>
# <!-- w9_9 -->
# <g id="node111" class="node">
# <title>w9_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_10&#45;&#45;w9_9 -->
# <g id="edge60" class="edge">
# <title>w9_10&#45;&#45;w9_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M719.55,-658.8C705.94,-658.8 683.2,-658.8 669.74,-658.8"/>
# </g>
# <!-- w1_7 -->
# <g id="node9" class="node">
# <title>w1_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_7 -->
# <g id="node146" class="node">
# <title>w2_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_7&#45;&#45;w2_7 -->
# <g id="edge67" class="edge">
# <title>w1_7&#45;&#45;w2_7</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M514.8,-94.05C514.8,-107.66 514.8,-130.4 514.8,-143.86"/>
# </g>
# <!-- w6_3 -->
# <g id="node10" class="node">
# <title>w6_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_18 -->
# <g id="node11" class="node">
# <title>w5_18</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1306.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_18&#45;&#45;w5_19 -->
# <g id="edge86" class="edge">
# <title>w5_18&#45;&#45;w5_19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1318.05,-370.8C1331.66,-370.8 1354.4,-370.8 1367.86,-370.8"/>
# </g>
# <!-- w2_13 -->
# <g id="node12" class="node">
# <title>w2_13</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="946.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_14 -->
# <g id="node197" class="node">
# <title>w2_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_13&#45;&#45;w2_14 -->
# <g id="edge4" class="edge">
# <title>w2_13&#45;&#45;w2_14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M958.05,-154.8C971.66,-154.8 994.4,-154.8 1007.86,-154.8"/>
# </g>
# <!-- w8_4 -->
# <g id="node13" class="node">
# <title>w8_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-586.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_4 -->
# <g id="node188" class="node">
# <title>w9_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w8_4&#45;&#45;w9_4 -->
# <g id="edge80" class="edge">
# <title>w8_4&#45;&#45;w9_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M298.8,-598.05C298.8,-611.66 298.8,-634.4 298.8,-647.86"/>
# </g>
# <!-- w3_2 -->
# <g id="node14" class="node">
# <title>w3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_3 -->
# <g id="node93" class="node">
# <title>w3_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2&#45;&#45;w3_3 -->
# <g id="edge22" class="edge">
# <title>w3_2&#45;&#45;w3_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M166.05,-226.8C179.66,-226.8 202.4,-226.8 215.86,-226.8"/>
# </g>
# <!-- w4_2 -->
# <g id="node96" class="node">
# <title>w4_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2&#45;&#45;w4_2 -->
# <g id="edge38" class="edge">
# <title>w3_2&#45;&#45;w4_2</ti

# %% [markdown]
# ----
#
# ## Scope

# %% [markdown]
# Make a random hexagonal grid labyrinth:

# %%
#% html
random-maze([8, 16], type => "hexagonal").dot(|%hex-opts):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="218pt"
#  viewBox="0.00 0.00 576.00 218.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.116855 0.116855) rotate(0) translate(4 1861.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-1861.6 4925.2,-1861.6 4925.2,4 -4,4"/>
# <!-- w232 -->
# <g id="node1" class="node">
# <title>w232</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3520.61" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w241 -->
# <g id="node9" class="node">
# <title>w241</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3645.32" cy="-1756.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w232&#45;&#45;w241 -->
# <g id="edge48" class="edge">
# <title>w232&#45;&#45;w241</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3545.85,-1814.23C3567.49,-1801.74 3598.5,-1783.83 3620.12,-1771.35"/>
# </g>
# <!-- w283 -->
# <g id="node2" class="node">
# <title>w283</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4268.86" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w289 -->
# <g id="node151" class="node">
# <title>w289</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4393.57" cy="-1756.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w283&#45;&#45;w289 -->
# <g id="edge9" class="edge">
# <title>w283&#45;&#45;w289</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4294.1,-1814.23C4315.73,-1801.74 4346.74,-1783.83 4368.37,-1771.35"/>
# </g>
# <!-- w161 -->
# <g id="node3" class="node">
# <title>w161</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2647.66" cy="-28.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w170 -->
# <g id="node26" class="node">
# <title>w170</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2772.37" cy="-100.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w161&#45;&#45;w170 -->
# <g id="edge206" class="edge">
# <title>w161&#45;&#45;w170</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2672.9,-43.37C2694.53,-55.86 2725.54,-73.77 2747.17,-86.25"/>
# </g>
# <!-- w63 -->
# <g id="node4" class="node">
# <title>w63</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1275.88" cy="-244.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w72 -->
# <g id="node155" class="node">
# <title>w72</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1400.58" cy="-316.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w63&#45;&#45;w72 -->
# <g id="edge164" class="edge">
# <title>w63&#45;&#45;w72</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1301.11,-259.37C1322.75,-271.86 1353.76,-289.77 1375.39,-302.25"/>
# </g>
# <!-- w231 -->
# <g id="node5" class="node">
# <title>w231</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3520.61" cy="-1540.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w240 -->
# <g id="node287" class="node">
# <title>w240</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3645.32" cy="-1612.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w231&#45;&#45;w240 -->
# <g id="edge92" class="edge">
# <title>w231&#45;&#45;w240</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3545.85,-1555.37C3567.49,-1567.86 3598.5,-1585.77 3620.12,-1598.25"/>
# </g>
# <!-- w175 -->
# <g id="node6" class="node">
# <title>w175</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2772.37" cy="-1108.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w184 -->
# <g id="node191" class="node">
# <title>w184</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2897.08" cy="-1180.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w175&#45;&#45;w184 -->
# <g id="edge127" class="edge">
# <title>w175&#45;&#45;w184</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2797.6,-1123.37C2819.24,-1135.86 2850.25,-1153.77 2871.88,-1166.25"/>
# </g>
# <!-- w28 -->
# <g id="node7" class="node">
# <title>w28</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="777.05" cy="-244.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w192 -->
# <g id="node8" class="node">
# <title>w192</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3021.78" cy="-964.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w201 -->
# <g id="node40" class="node">
# <title>w201</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3146.49" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w192&#45;&#45;w201 -->
# <g id="edge218" class="edge">
# <title>w192&#45;&#45;w201</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3047.02,-950.23C3068.66,-937.74 3099.67,-919.83 3121.29,-907.35"/>
# </g>
# <!-- w250 -->
# <g id="node35" class="node">
# <title>w250</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3770.03" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w241&#45;&#45;w250 -->
# <g id="edge227" class="edge">
# <title>w241&#45;&#45;w250</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3670.56,-1771.37C3692.19,-1783.86 3723.21,-1801.77 3744.83,-1814.25"/>
# </g>
# <!-- w12 -->
# <g id="node10" class="node">
# <title>w12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="402.92" cy="-748.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w13 -->
# <g id="node82" class="node">
# <title>w13</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="402.92" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w12&#45;&#45;w13 -->
# <g id="edge122" class="edge">
# <title>w12&#45;&#45;w13</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M402.92,-777.94C402.92,-802.92 402.92,-838.73 402.92,-863.7"/>
# </g>
# <!-- w8 -->
# <g id="node173" class="node">
# <title>w8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="278.22" cy="-676.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w12&#45;&#45;w8 -->
# <g id="edge123" class="edge">
# <title>w12&#45;&#45;w8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M377.69,-734.23C356.05,-721.74 325.04,-703.83 303.41,-691.35"/>
# </g>
# <!-- w17 -->
# <g id="node257" class="node">
# <title>w17</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="527.63" cy="-676.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w12&#45;&#45;w17 -->
# <g id="edge121" class="edge">
# <title>w12&#45;&#45;w17</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M428.16,-734.23C449.8,-721.74 480.81,-703.83 502.43,-691.35"/>
# </g>
# <!-- w39 -->
# <g id="node11" class="node">
# <title>w39</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="901.75" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w48 -->
# <g id="node73" class="node">
# <title>w48</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1026.46" cy="-964.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w39&#45;&#45;w48 -->
# <g id="edge199" class="edge">
# <title>w39&#45;&#45;w48</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M926.99,-907.37C948.63,-919.86 979.64,-937.77 1001.26,-950.25"/>
# </g>
# <!-- w91 -->
# <g id="node12" class="node">
# <title>w91</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1650" cy="-460.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w244 -->
# <g id="node13" class="node">
# <title>w244</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3770.03" cy="-532.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w245 -->
# <g id="node198" class="node">
# <title>w245</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3770.03" cy="-676.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w244&#45;&#45;w245 -->
# <g id="edge191" class="edge">
# <title>w244&#45;&#45;w245</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3770.03,-561.94C3770.03,-586.92 3770.03,-622.73 3770.03,-647.7"/>
# </g>
# <!-- w122 -->
# <g id="node14" class="node">
# <title>w122</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2024.12" cy="-1396.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w219 -->
# <g id="node15" class="node">
# <title>w219</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3395.91" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w228 -->
# <g id="node165" class="node">
# <title>w228</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3520.61" cy="-964.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w219&#45;&#45;w228 -->
# <g id="edge147" class="edge">
# <title>w219&#45;&#45;w228</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3421.14,-907.37C3442.78,-919.86 3473.79,-937.77 3495.42,-950.25"/>

# %% [markdown]
# `random-maze` can be given different properties:

# %%
random-maze("properties")
# Out:
# [type dimensions walls paths solution start end]

# %% [markdown]
# If the properties argument is `Whatever`, then an association with all properties is returned:

# %%
random-maze(5, props => Whatever)
# Out:
# {dimensions => [5 5], end => 3_3, paths => Graph(vertexes => 16, edges => 15, directed => False), solution => [0_0 0_1 1_1 1_0 2_0 2_1 2_2 3_2 3_3], start => 0_0, type => rectangular, walls => Graph(vertexes => 23, edges => 21, directed => False)}

# %% [markdown]
# ---
#
# ## Options

# %% [markdown]
# #### Type

# %% [markdown]
# The option `:$type` specifies the type grid graphs used to make the labyrinth. It takes the values "rectangular" and "hexagonal":

# %%
#% html
<rectangular hexagonal>.map({ random-maze(7, type => $_) }).List
andthen $_.head.dot(|merge-hash(%opts , {:3size}), :svg) ~ $_.tail.dot(|merge-hash(%hex-opts , {size => 4.5}), :svg)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="216pt" height="216pt"
#  viewBox="0.00 0.00 216.00 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.467938 0.467938) rotate(0) translate(4 457.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-457.6 457.6,-457.6 457.6,4 -4,4"/>
# <!-- w6_0 -->
# <g id="node1" class="node">
# <title>w6_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_1 -->
# <g id="node29" class="node">
# <title>w6_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_0&#45;&#45;w6_1 -->
# <g id="edge2" class="edge">
# <title>w6_0&#45;&#45;w6_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M22.05,-442.8C35.66,-442.8 58.4,-442.8 71.86,-442.8"/>
# </g>
# <!-- w2_3 -->
# <g id="node2" class="node">
# <title>w2_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_3 -->
# <g id="node9" class="node">
# <title>w3_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_3&#45;&#45;w3_3 -->
# <g id="edge4" class="edge">
# <title>w2_3&#45;&#45;w3_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-166.05C226.8,-179.66 226.8,-202.4 226.8,-215.86"/>
# </g>
# <!-- w2_4 -->
# <g id="node24" class="node">
# <title>w2_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_3&#45;&#45;w2_4 -->
# <g id="edge36" class="edge">
# <title>w2_3&#45;&#45;w2_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M238.05,-154.8C251.66,-154.8 274.4,-154.8 287.86,-154.8"/>
# </g>
# <!-- w5_3 -->
# <g id="node3" class="node">
# <title>w5_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_4 -->
# <g id="node26" class="node">
# <title>w5_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_3&#45;&#45;w5_4 -->
# <g id="edge23" class="edge">
# <title>w5_3&#45;&#45;w5_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M238.05,-370.8C251.66,-370.8 274.4,-370.8 287.86,-370.8"/>
# </g>
# <!-- w6_3 -->
# <g id="node44" class="node">
# <title>w6_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_3&#45;&#45;w6_3 -->
# <g id="edge29" class="edge">
# <title>w5_3&#45;&#45;w6_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-382.05C226.8,-395.66 226.8,-418.4 226.8,-431.86"/>
# </g>
# <!-- w0_3 -->
# <g id="node4" class="node">
# <title>w0_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_4 -->
# <g id="node8" class="node">
# <title>w0_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_3&#45;&#45;w0_4 -->
# <g id="edge21" class="edge">
# <title>w0_3&#45;&#45;w0_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M238.05,-10.8C251.66,-10.8 274.4,-10.8 287.86,-10.8"/>
# </g>
# <!-- w5_6 -->
# <g id="node5" class="node">
# <title>w5_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_1 -->
# <g id="node6" class="node">
# <title>w0_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_2 -->
# <g id="node19" class="node">
# <title>w0_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_1&#45;&#45;w0_2 -->
# <g id="edge42" class="edge">
# <title>w0_1&#45;&#45;w0_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M94.05,-10.8C107.66,-10.8 130.4,-10.8 143.86,-10.8"/>
# </g>
# <!-- w1_5 -->
# <g id="node7" class="node">
# <title>w1_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_5 -->
# <g id="node11" class="node">
# <title>w2_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_5&#45;&#45;w2_5 -->
# <g id="edge38" class="edge">
# <title>w1_5&#45;&#45;w2_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M370.8,-94.05C370.8,-107.66 370.8,-130.4 370.8,-143.86"/>
# </g>
# <!-- w0_5 -->
# <g id="node33" class="node">
# <title>w0_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_4&#45;&#45;w0_5 -->
# <g id="edge44" class="edge">
# <title>w0_4&#45;&#45;w0_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M310.05,-10.8C323.66,-10.8 346.4,-10.8 359.86,-10.8"/>
# </g>
# <!-- w0_6 -->
# <g id="node10" class="node">
# <title>w0_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_6 -->
# <g id="node40" class="node">
# <title>w1_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_6&#45;&#45;w1_6 -->
# <g id="edge11" class="edge">
# <title>w0_6&#45;&#45;w1_6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M442.8,-22.05C442.8,-35.66 442.8,-58.4 442.8,-71.86"/>
# </g>
# <!-- w2_6 -->
# <g id="node28" class="node">
# <title>w2_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_5&#45;&#45;w2_6 -->
# <g id="edge37" class="edge">
# <title>w2_5&#45;&#45;w2_6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M382.05,-154.8C395.66,-154.8 418.4,-154.8 431.86,-154.8"/>
# </g>
# <!-- w3_5 -->
# <g id="node12" class="node">
# <title>w3_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_5 -->
# <g id="node36" class="node">
# <title>w4_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_5&#45;&#45;w4_5 -->
# <g id="edge24" class="edge">
# <title>w3_5&#45;&#45;w4_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M370.8,-238.05C370.8,-251.66 370.8,-274.4 370.8,-287.86"/>
# </g>
# <!-- w3_4 -->
# <g id="node13" class="node">
# <title>w3_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_4 -->
# <g id="node42" class="node">
# <title>w4_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_4&#45;&#45;w4_4 -->
# <g id="edge43" class="edge">
# <title>w3_4&#45;&#45;w4_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M298.8,-238.05C298.8,-251.66 298.8,-274.4 298.8,-287.86"/>
# </g>
# <!-- w2_2 -->
# <g id="node14" class="node">
# <title>w2_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2 -->
# <g id="node41" class="node">
# <title>w3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_2&#45;&#45;w3_2 -->
# <g id="edge45" class="edge">
# <title>w2_2&#45;&#45;w3_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M154.8,-166.05C154.8,-179.66 154.8,-202.4 154.8,-215.86"/>
# </g>
# <!-- w1_0 -->
# <g id="node15" class="node">
# <title>w1_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_0 -->
# <g id="node34" class="node">
# <title>w2_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_0&#45;&#45;w2_0 -->
# <g id="edge10" class="edge">
# <title>w1_0&#45;&#45;w2_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M10.8,-94.05C10.8,-107.66 10.8,-130.4 10.8,-143.86"/>
# </g>
# <!-- w1_2 -->
# <g id="node16" class="node">
# <title>w1_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-82.8" rx="10

# %% [markdown]
# ---
#
# ## Applications

# %% [markdown]
# Make a rectangular grid labyrinth and show it together with a solution:

# %%
#%html
my %res = random-maze([12, 24], props => <walls paths solution>);

display-maze(%res, |%opts)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="281pt"
#  viewBox="0.00 0.00 576.00 281.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.341718 0.341718) rotate(0) translate(4 817.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-817.6 1681.6,-817.6 1681.6,4 -4,4"/>
# <!-- w3_4 -->
# <g id="node1" class="node">
# <title>w3_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_14 -->
# <g id="node2" class="node">
# <title>w7_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w8_14 -->
# <g id="node227" class="node">
# <title>w8_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-586.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_14&#45;&#45;w8_14 -->
# <g id="edge185" class="edge">
# <title>w7_14&#45;&#45;w8_14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1018.8,-526.05C1018.8,-539.66 1018.8,-562.4 1018.8,-575.86"/>
# </g>
# <!-- w1_22 -->
# <g id="node3" class="node">
# <title>w1_22</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1594.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_23 -->
# <g id="node237" class="node">
# <title>w1_23</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1666.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_22&#45;&#45;w1_23 -->
# <g id="edge212" class="edge">
# <title>w1_22&#45;&#45;w1_23</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1606.05,-82.8C1619.66,-82.8 1642.4,-82.8 1655.86,-82.8"/>
# </g>
# <!-- w0_11 -->
# <g id="node4" class="node">
# <title>w0_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_11 -->
# <g id="node159" class="node">
# <title>w1_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_11&#45;&#45;w1_11 -->
# <g id="edge284" class="edge">
# <title>w0_11&#45;&#45;w1_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M802.8,-22.05C802.8,-35.66 802.8,-58.4 802.8,-71.86"/>
# </g>
# <!-- w0_12 -->
# <g id="node222" class="node">
# <title>w0_12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="874.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_11&#45;&#45;w0_12 -->
# <g id="edge248" class="edge">
# <title>w0_11&#45;&#45;w0_12</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M814.05,-10.8C827.66,-10.8 850.4,-10.8 863.86,-10.8"/>
# </g>
# <!-- w9_17 -->
# <g id="node5" class="node">
# <title>w9_17</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1234.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_18 -->
# <g id="node11" class="node">
# <title>w9_18</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1306.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_17&#45;&#45;w9_18 -->
# <g id="edge202" class="edge">
# <title>w9_17&#45;&#45;w9_18</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1246.05,-658.8C1259.66,-658.8 1282.4,-658.8 1295.86,-658.8"/>
# </g>
# <!-- w3_14 -->
# <g id="node6" class="node">
# <title>w3_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_14 -->
# <g id="node285" class="node">
# <title>w4_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_14&#45;&#45;w4_14 -->
# <g id="edge93" class="edge">
# <title>w3_14&#45;&#45;w4_14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1018.8,-238.05C1018.8,-251.66 1018.8,-274.4 1018.8,-287.86"/>
# </g>
# <!-- w5_19 -->
# <g id="node7" class="node">
# <title>w5_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_19 -->
# <g id="node13" class="node">
# <title>w6_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_19&#45;&#45;w6_19 -->
# <g id="edge250" class="edge">
# <title>w5_19&#45;&#45;w6_19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1378.8,-382.05C1378.8,-395.66 1378.8,-418.4 1378.8,-431.86"/>
# </g>
# <!-- w5_20 -->
# <g id="node273" class="node">
# <title>w5_20</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1450.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_19&#45;&#45;w5_20 -->
# <g id="edge251" class="edge">
# <title>w5_19&#45;&#45;w5_20</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1390.05,-370.8C1403.66,-370.8 1426.4,-370.8 1439.86,-370.8"/>
# </g>
# <!-- w3_12 -->
# <g id="node8" class="node">
# <title>w3_12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="874.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_12 -->
# <g id="node152" class="node">
# <title>w4_12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="874.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_12&#45;&#45;w4_12 -->
# <g id="edge7" class="edge">
# <title>w3_12&#45;&#45;w4_12</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M874.8,-238.05C874.8,-251.66 874.8,-274.4 874.8,-287.86"/>
# </g>
# <!-- w2_10 -->
# <g id="node9" class="node">
# <title>w2_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_11 -->
# <g id="node161" class="node">
# <title>w2_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_10&#45;&#45;w2_11 -->
# <g id="edge131" class="edge">
# <title>w2_10&#45;&#45;w2_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M742.05,-154.8C755.66,-154.8 778.4,-154.8 791.86,-154.8"/>
# </g>
# <!-- w10_3 -->
# <g id="node10" class="node">
# <title>w10_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-730.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_3 -->
# <g id="node78" class="node">
# <title>w9_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w10_3&#45;&#45;w9_3 -->
# <g id="edge230" class="edge">
# <title>w10_3&#45;&#45;w9_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-719.55C226.8,-705.94 226.8,-683.2 226.8,-669.74"/>
# </g>
# <!-- w4_19 -->
# <g id="node12" class="node">
# <title>w4_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_19 -->
# <g id="node120" class="node">
# <title>w7_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_19&#45;&#45;w7_19 -->
# <g id="edge78" class="edge">
# <title>w6_19&#45;&#45;w7_19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1378.8,-454.05C1378.8,-467.66 1378.8,-490.4 1378.8,-503.86"/>
# </g>
# <!-- w5_9 -->
# <g id="node14" class="node">
# <title>w5_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_19 -->
# <g id="node15" class="node">
# <title>w3_19</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1378.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_20 -->
# <g id="node271" class="node">
# <title>w3_20</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1450.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_19&#45;&#45;w3_20 -->
# <g id="edge226" class="edge">
# <title>w3_19&#45;&#45;w3_20</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1390.05,-226.8C1403.66,-226.8 1426.4,-226.8 1439.86,-226.8"/>
# </g>
# <!-- w0_13 -->
# <g id="node16" class="node">
# <title>w0_13</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="946.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_14 -->
# <g id="node140" class="node">
# <title>w0_14</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1018.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_13&#45;&#45;w0_14 -->
# <g id="edge100" class="edge">
# <title>w0_13&#45;&#45;w0_14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M958.05,-10.8C971.66,-10.8 994.4,-10.8 1007.86,-10.8"/>

# %% [markdown]
# Make a hexagonal grid labyrinth and show it together with a solution:

# %%
#%html
my %res = random-maze([12, 24], type => 'hexagonal', props => <walls paths solution>);

display-maze(%res, |%hex-opts)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="212pt"
#  viewBox="0.00 0.00 576.00 212.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.077593 0.077593) rotate(0) translate(4 2725.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-2725.6 7419.35,-2725.6 7419.35,4 -4,4"/>
# <!-- w236 -->
# <g id="node1" class="node">
# <title>w236</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2897.08" cy="-748.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w237 -->
# <g id="node609" class="node">
# <title>w237</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2897.08" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w236&#45;&#45;w237 -->
# <g id="edge413" class="edge">
# <title>w236&#45;&#45;w237</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2897.08,-777.94C2897.08,-802.92 2897.08,-838.73 2897.08,-863.7"/>
# </g>
# <!-- 26 -->
# <g id="node2" class="node">
# <title>26</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="1275.88" cy="-820.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- 32 -->
# <g id="node404" class="node">
# <title>32</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="1400.58" cy="-1036.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- 26&#45;&#45;32 -->
# <g id="edge709" class="edge">
# <title>26&#45;&#45;32</title>
# <path fill="none" stroke="DarkOrange" stroke-width="32" d="M1290.43,-846C1314.39,-887.51 1361.9,-969.8 1385.93,-1011.43"/>
# </g>
# <!-- 17 -->
# <g id="node3" class="node">
# <title>17</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="1026.46" cy="-820.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- 17&#45;&#45;26 -->
# <g id="edge694" class="edge">
# <title>17&#45;&#45;26</title>
# <path fill="none" stroke="DarkOrange" stroke-width="32" d="M1055.56,-820.8C1103.49,-820.8 1198.52,-820.8 1246.58,-820.8"/>
# </g>
# <!-- 21 -->
# <g id="node570" class="node">
# <title>21</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="1151.17" cy="-604.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- 17&#45;&#45;21 -->
# <g id="edge653" class="edge">
# <title>17&#45;&#45;21</title>
# <path fill="none" stroke="DarkOrange" stroke-width="32" d="M1041.01,-795.6C1064.98,-754.09 1112.49,-671.8 1136.52,-630.17"/>
# </g>
# <!-- w531 -->
# <g id="node4" class="node">
# <title>w531</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5640.64" cy="-2620.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w544 -->
# <g id="node425" class="node">
# <title>w544</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5765.35" cy="-2692.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w531&#45;&#45;w544 -->
# <g id="edge39" class="edge">
# <title>w531&#45;&#45;w544</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M5665.88,-2635.37C5687.52,-2647.86 5718.53,-2665.77 5740.15,-2678.25"/>
# </g>
# <!-- w53 -->
# <g id="node5" class="node">
# <title>w53</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1026.46" cy="-1972.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w63 -->
# <g id="node138" class="node">
# <title>w63</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1151.17" cy="-2044.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w53&#45;&#45;w63 -->
# <g id="edge518" class="edge">
# <title>w53&#45;&#45;w63</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1051.7,-1987.37C1073.33,-1999.86 1104.34,-2017.77 1125.97,-2030.25"/>
# </g>
# <!-- w488 -->
# <g id="node6" class="node">
# <title>w488</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5266.52" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w489 -->
# <g id="node431" class="node">
# <title>w489</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5266.52" cy="-1972.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w488&#45;&#45;w489 -->
# <g id="edge4" class="edge">
# <title>w488&#45;&#45;w489</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M5266.52,-1857.94C5266.52,-1882.92 5266.52,-1918.73 5266.52,-1943.7"/>
# </g>
# <!-- w501 -->
# <g id="node461" class="node">
# <title>w501</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5391.23" cy="-1756.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w488&#45;&#45;w501 -->
# <g id="edge103" class="edge">
# <title>w488&#45;&#45;w501</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M5291.76,-1814.23C5313.39,-1801.74 5344.41,-1783.83 5366.03,-1771.35"/>
# </g>
# <!-- w426 -->
# <g id="node7" class="node">
# <title>w426</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4642.98" cy="-2476.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w427 -->
# <g id="node328" class="node">
# <title>w427</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4642.98" cy="-2620.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w426&#45;&#45;w427 -->
# <g id="edge238" class="edge">
# <title>w426&#45;&#45;w427</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4642.98,-2505.94C4642.98,-2530.92 4642.98,-2566.73 4642.98,-2591.7"/>
# </g>
# <!-- w3 -->
# <g id="node8" class="node">
# <title>w3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="153.51" cy="-316.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w4 -->
# <g id="node103" class="node">
# <title>w4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="153.51" cy="-460.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w3&#45;&#45;w4 -->
# <g id="edge180" class="edge">
# <title>w3&#45;&#45;w4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M153.51,-345.94C153.51,-370.92 153.51,-406.73 153.51,-431.7"/>
# </g>
# <!-- w301 -->
# <g id="node9" class="node">
# <title>w301</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3520.61" cy="-676.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w314 -->
# <g id="node151" class="node">
# <title>w314</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3645.32" cy="-748.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w301&#45;&#45;w314 -->
# <g id="edge446" class="edge">
# <title>w301&#45;&#45;w314</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3545.85,-691.37C3567.49,-703.86 3598.5,-721.77 3620.12,-734.25"/>
# </g>
# <!-- w76 -->
# <g id="node10" class="node">
# <title>w76</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1275.88" cy="-2404.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w88 -->
# <g id="node618" class="node">
# <title>w88</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1400.58" cy="-2476.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w76&#45;&#45;w88 -->
# <g id="edge17" class="edge">
# <title>w76&#45;&#45;w88</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M1301.11,-2419.37C1322.75,-2431.86 1353.76,-2449.77 1375.39,-2462.25"/>
# </g>
# <!-- w543 -->
# <g id="node11" class="node">
# <title>w543</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5765.35" cy="-2404.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w556 -->
# <g id="node626" class="node">
# <title>w556</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5890.06" cy="-2476.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w543&#45;&#45;w556 -->
# <g id="edge622" class="edge">
# <title>w543&#45;&#45;w556</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M5790.59,-2419.37C5812.22,-2431.86 5843.24,-2449.77 5864.86,-2462.25"/>
# </g>
# <!-- w245 -->
# <g id="node12" class="node">
# <title>w245</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2897.08" cy="-2620.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w258 -->
# <g id="node406" class="node">
# <title>w258</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3021.78" cy="-2692.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w245&#45;&#45;w258 -->
# <g id="edge531" class="edge">
# <title>w245&#45;&#45;w258</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M2922.31,-2635.37C2943.95,-2647.86 2974.96,-2665.77 2996.58,-2678.25"/>
# </g>
# <!-- w321 -->
# <g id="node13" class="node">
# <title>w321</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3645.32" cy="-2188.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w71 -->
# <g id="node14" class="node">
# <title>w71</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1275.88" cy="-1396.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w83 -->
# <g id="node322" class="node">
# <title>w83</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1400

# %% [markdown]
# Generate 500 labyrinths (in parallel):

# %%
my @labs = (^500).race(:4degree, :125batch).map({ random-maze(12, props => <walls paths solution>) });
deduce-type(@labs)
# Out:
# Vector(Struct([paths, solution, walls], [Graph, Array, Graph]), 500)

# %% [markdown]
# Show the histogram of the shortest path solution lengths:

# %%
#% js
js-d3-histogram(@labs.map(*<solution>)».elems, :$background)

# %% [markdown]
# Show the labyrinths with the smallest and largest shortest paths solutions:

# %%
In[]:= Show[#Walls, HighlightGraph[#, #] &@Subgraph[#Paths, #Solution], ImageSize -> 230] & /@ SortBy[labs, Length[#Solution] &][[{1, -1}]]

# %%
#% html
@labs.sort(*<solution>.elems).List
andthen display-maze($_.head, |merge-hash(%opts , {:3size})) ~ display-maze($_.tail, |merge-hash(%opts , {size => 3}))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="216pt" height="216pt"
#  viewBox="0.00 0.00 216.00 216.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.262902 0.262902) rotate(0) translate(4 817.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-817.6 817.6,-817.6 817.6,4 -4,4"/>
# <!-- w9_9 -->
# <g id="node1" class="node">
# <title>w9_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 3_3 -->
# <g id="node2" class="node">
# <title>3_3</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="262.8" cy="-262.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 4_3 -->
# <g id="node65" class="node">
# <title>4_3</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="262.8" cy="-334.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 3_3&#45;&#45;4_3 -->
# <g id="edge157" class="edge">
# <title>3_3&#45;&#45;4_3</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M262.8,-274.05C262.8,-287.66 262.8,-310.4 262.8,-323.86"/>
# </g>
# <!-- w2_8 -->
# <g id="node3" class="node">
# <title>w2_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10 -->
# <g id="node4" class="node">
# <title>w0_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_10 -->
# <g id="node83" class="node">
# <title>w1_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10&#45;&#45;w1_10 -->
# <g id="edge86" class="edge">
# <title>w0_10&#45;&#45;w1_10</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M730.8,-22.05C730.8,-35.66 730.8,-58.4 730.8,-71.86"/>
# </g>
# <!-- w0_11 -->
# <g id="node119" class="node">
# <title>w0_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10&#45;&#45;w0_11 -->
# <g id="edge102" class="edge">
# <title>w0_10&#45;&#45;w0_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M742.05,-10.8C755.66,-10.8 778.4,-10.8 791.86,-10.8"/>
# </g>
# <!-- w0_9 -->
# <g id="node134" class="node">
# <title>w0_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_10&#45;&#45;w0_9 -->
# <g id="edge89" class="edge">
# <title>w0_10&#45;&#45;w0_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M719.55,-10.8C705.94,-10.8 683.2,-10.8 669.74,-10.8"/>
# </g>
# <!-- 3_1 -->
# <g id="node5" class="node">
# <title>3_1</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="118.8" cy="-262.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 3_2 -->
# <g id="node144" class="node">
# <title>3_2</title>
# <ellipse fill="DarkOrange" stroke="DarkOrange" cx="190.8" cy="-262.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- 3_1&#45;&#45;3_2 -->
# <g id="edge146" class="edge">
# <title>3_1&#45;&#45;3_2</title>
# <path fill="none" stroke="DarkOrange" stroke-width="12" d="M130.05,-262.8C143.66,-262.8 166.4,-262.8 179.86,-262.8"/>
# </g>
# <!-- w2_4 -->
# <g id="node6" class="node">
# <title>w2_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_5 -->
# <g id="node50" class="node">
# <title>w2_5</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="370.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_4&#45;&#45;w2_5 -->
# <g id="edge131" class="edge">
# <title>w2_4&#45;&#45;w2_5</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M310.05,-154.8C323.66,-154.8 346.4,-154.8 359.86,-154.8"/>
# </g>
# <!-- w2_11 -->
# <g id="node7" class="node">
# <title>w2_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_11 -->
# <g id="node59" class="node">
# <title>w3_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_11&#45;&#45;w3_11 -->
# <g id="edge19" class="edge">
# <title>w2_11&#45;&#45;w3_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M802.8,-166.05C802.8,-179.66 802.8,-202.4 802.8,-215.86"/>
# </g>
# <!-- w7_3 -->
# <g id="node8" class="node">
# <title>w7_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-514.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w8_3 -->
# <g id="node85" class="node">
# <title>w8_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-586.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w7_3&#45;&#45;w8_3 -->
# <g id="edge28" class="edge">
# <title>w7_3&#45;&#45;w8_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M226.8,-526.05C226.8,-539.66 226.8,-562.4 226.8,-575.86"/>
# </g>
# <!-- w2_2 -->
# <g id="node9" class="node">
# <title>w2_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2 -->
# <g id="node36" class="node">
# <title>w3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_2&#45;&#45;w3_2 -->
# <g id="edge2" class="edge">
# <title>w2_2&#45;&#45;w3_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M154.8,-166.05C154.8,-179.66 154.8,-202.4 154.8,-215.86"/>
# </g>
# <!-- w2_3 -->
# <g id="node104" class="node">
# <title>w2_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_2&#45;&#45;w2_3 -->
# <g id="edge1" class="edge">
# <title>w2_2&#45;&#45;w2_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M166.05,-154.8C179.66,-154.8 202.4,-154.8 215.86,-154.8"/>
# </g>
# <!-- w9_7 -->
# <g id="node10" class="node">
# <title>w9_7</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="514.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_8 -->
# <g id="node54" class="node">
# <title>w9_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_7&#45;&#45;w9_8 -->
# <g id="edge139" class="edge">
# <title>w9_7&#45;&#45;w9_8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M526.05,-658.8C539.66,-658.8 562.4,-658.8 575.86,-658.8"/>
# </g>
# <!-- w8_6 -->
# <g id="node11" class="node">
# <title>w8_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-586.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_6 -->
# <g id="node23" class="node">
# <title>w9_6</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="442.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w8_6&#45;&#45;w9_6 -->
# <g id="edge14" class="edge">
# <title>w8_6&#45;&#45;w9_6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M442.8,-598.05C442.8,-611.66 442.8,-634.4 442.8,-647.86"/>
# </g>
# <!-- w3_8 -->
# <g id="node12" class="node">
# <title>w3_8</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="586.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_9 -->
# <g id="node102" class="node">
# <title>w3_9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="658.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_8&#45;&#45;w3_9 -->
# <g id="edge132" class="edge">
# <title>w3_8&#45;&#45;w3_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M598.05,-226.8C611.66,-226.8 634.4,-226.8 647.86,-226.8"/>
# </g>
# <!-- w9_10 -->
# <g id="node13" class="node">
# <title>w9_10</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="730.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_10&#45;&#45;w9_9 -->
# <g id="edge109" class="edge">
# <title>w9_10&#45;&#45;w9_9</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M719.55,-658.8C705.94,-658.8 683.2,-658.8 669.74,-658.8"/>
# </g>
# <!-- w5_0 -->
# <g id="node14" class="node">
# <title>w5_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-370.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w6_0 -->
# <g id="node60" class="node">
# <title>w6_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-442.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w5_0&#45;&#45;w6_0 -->
# <g id="edge98" class="edge">
# <title>w5_0&#45;&#45;w6_0</title>
# <path fill="none" stroke="S

# %% [markdown]
# ----
#
# ## Properties and Relations

# %% [markdown]
# ### Possible Issues

# %% [markdown]
# For larger size values the labyrinth generation might be slow.

# %% [markdown]
# ---
#
# ## Neat Examples

# %% [markdown]
# Larger rectangular grid maze:

# %%
#%html
random-maze([30, 60]).dot(|%opts):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="285pt"
#  viewBox="0.00 0.00 576.00 285.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.134655 0.134655) rotate(0) translate(4 2113.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-2113.6 4273.6,-2113.6 4273.6,4 -4,4"/>
# <!-- w15_49 -->
# <g id="node1" class="node">
# <title>w15_49</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3538.8" cy="-1090.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w16_49 -->
# <g id="node1578" class="node">
# <title>w16_49</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3538.8" cy="-1162.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w15_49&#45;&#45;w16_49 -->
# <g id="edge334" class="edge">
# <title>w15_49&#45;&#45;w16_49</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M3538.8,-1102.05C3538.8,-1115.66 3538.8,-1138.4 3538.8,-1151.86"/>
# </g>
# <!-- w3_16 -->
# <g id="node2" class="node">
# <title>w3_16</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1162.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_17 -->
# <g id="node1619" class="node">
# <title>w3_17</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1234.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_16&#45;&#45;w3_17 -->
# <g id="edge1299" class="edge">
# <title>w3_16&#45;&#45;w3_17</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1174.05,-226.8C1187.66,-226.8 1210.4,-226.8 1223.86,-226.8"/>
# </g>
# <!-- w13_15 -->
# <g id="node3" class="node">
# <title>w13_15</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1090.8" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w14_15 -->
# <g id="node535" class="node">
# <title>w14_15</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1090.8" cy="-1018.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w13_15&#45;&#45;w14_15 -->
# <g id="edge1103" class="edge">
# <title>w13_15&#45;&#45;w14_15</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1090.8,-958.05C1090.8,-971.66 1090.8,-994.4 1090.8,-1007.86"/>
# </g>
# <!-- w13_16 -->
# <g id="node1560" class="node">
# <title>w13_16</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1162.8" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w13_15&#45;&#45;w13_16 -->
# <g id="edge1021" class="edge">
# <title>w13_15&#45;&#45;w13_16</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1102.05,-946.8C1115.66,-946.8 1138.4,-946.8 1151.86,-946.8"/>
# </g>
# <!-- w25_27 -->
# <g id="node4" class="node">
# <title>w25_27</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1954.8" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w25_28 -->
# <g id="node707" class="node">
# <title>w25_28</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2026.8" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w25_27&#45;&#45;w25_28 -->
# <g id="edge1677" class="edge">
# <title>w25_27&#45;&#45;w25_28</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1966.05,-1810.8C1979.66,-1810.8 2002.4,-1810.8 2015.86,-1810.8"/>
# </g>
# <!-- w3_42 -->
# <g id="node5" class="node">
# <title>w3_42</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3034.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_43 -->
# <g id="node1135" class="node">
# <title>w3_43</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3106.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_42&#45;&#45;w3_43 -->
# <g id="edge370" class="edge">
# <title>w3_42&#45;&#45;w3_43</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M3046.05,-226.8C3059.66,-226.8 3082.4,-226.8 3095.86,-226.8"/>
# </g>
# <!-- w23_33 -->
# <g id="node6" class="node">
# <title>w23_33</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2386.8" cy="-1666.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w24_33 -->
# <g id="node1677" class="node">
# <title>w24_33</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2386.8" cy="-1738.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w23_33&#45;&#45;w24_33 -->
# <g id="edge177" class="edge">
# <title>w23_33&#45;&#45;w24_33</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M2386.8,-1678.05C2386.8,-1691.66 2386.8,-1714.4 2386.8,-1727.86"/>
# </g>
# <!-- w9_21 -->
# <g id="node7" class="node">
# <title>w9_21</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1522.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_22 -->
# <g id="node219" class="node">
# <title>w9_22</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1594.8" cy="-658.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w9_21&#45;&#45;w9_22 -->
# <g id="edge1250" class="edge">
# <title>w9_21&#45;&#45;w9_22</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1534.05,-658.8C1547.66,-658.8 1570.4,-658.8 1583.86,-658.8"/>
# </g>
# <!-- w28_27 -->
# <g id="node8" class="node">
# <title>w28_27</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1954.8" cy="-2026.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w29_27 -->
# <g id="node763" class="node">
# <title>w29_27</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="1954.8" cy="-2098.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w28_27&#45;&#45;w29_27 -->
# <g id="edge813" class="edge">
# <title>w28_27&#45;&#45;w29_27</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1954.8,-2038.05C1954.8,-2051.66 1954.8,-2074.4 1954.8,-2087.86"/>
# </g>
# <!-- w28_28 -->
# <g id="node897" class="node">
# <title>w28_28</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2026.8" cy="-2026.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w28_27&#45;&#45;w28_28 -->
# <g id="edge812" class="edge">
# <title>w28_27&#45;&#45;w28_28</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M1966.05,-2026.8C1979.66,-2026.8 2002.4,-2026.8 2015.86,-2026.8"/>
# </g>
# <!-- w13_11 -->
# <g id="node9" class="node">
# <title>w13_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-946.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w14_11 -->
# <g id="node1612" class="node">
# <title>w14_11</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="802.8" cy="-1018.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w13_11&#45;&#45;w14_11 -->
# <g id="edge1332" class="edge">
# <title>w13_11&#45;&#45;w14_11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M802.8,-958.05C802.8,-971.66 802.8,-994.4 802.8,-1007.86"/>
# </g>
# <!-- w20_3 -->
# <g id="node10" class="node">
# <title>w20_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-1450.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w12_12 -->
# <g id="node11" class="node">
# <title>w12_12</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="874.8" cy="-874.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w12_13 -->
# <g id="node1218" class="node">
# <title>w12_13</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="946.8" cy="-874.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w12_12&#45;&#45;w12_13 -->
# <g id="edge596" class="edge">
# <title>w12_12&#45;&#45;w12_13</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M886.05,-874.8C899.66,-874.8 922.4,-874.8 935.86,-874.8"/>
# </g>
# <!-- w25_34 -->
# <g id="node12" class="node">
# <title>w25_34</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2458.8" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w25_35 -->
# <g id="node1393" class="node">
# <title>w25_35</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2530.8" cy="-1810.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w25_34&#45;&#45;w25_35 -->
# <g id="edge782" class="edge">
# <title>w25_34&#45;&#45;w25_35</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M2470.05,-1810.8C2483.66,-1810.8 2506.4,-1810.8 2519.86,-1810.8"/>
# </g>
# <!-- w26_34 -->
# <g id="node1685" class="node">
# <title>w26_34</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="2458.8" cy="-1882.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w25_34&#45;&#45;w26_34 -->
# <g id="edge53" class="edge">
# <title>w25_34&#45;&#45;w26_34</title>
# <path fill="none" stroke="SteelBlue" stroke-width="12" d="M2458.8,-1822.05C2458.8,-1835.66 2458.8,-1858.4 2458.8,-1871.86"/>
# </g>
# <!-- w11_52 -->
# <g id="node13" class="node">
# <title>w11_52</title>
# <ellipse fill="SteelBlue" stroke="Blac

# %% [markdown]
# Larger hexagonal grid maze:

# %%
#%html
random-maze([20, 40], type => 'hexagonal').dot(|%hex-opts):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="207pt"
#  viewBox="0.00 0.00 576.00 207.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.046408 0.046408) rotate(0) translate(4 4453.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-4453.6 12407.66,-4453.6 12407.66,4 -4,4"/>
# <!-- w1161 -->
# <g id="node1" class="node">
# <title>w1161</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="7885.38" cy="-1756.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1182 -->
# <g id="node463" class="node">
# <title>w1182</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="8010.09" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1161&#45;&#45;w1182 -->
# <g id="edge424" class="edge">
# <title>w1161&#45;&#45;w1182</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M7910.62,-1771.37C7932.26,-1783.86 7963.27,-1801.77 7984.89,-1814.25"/>
# </g>
# <!-- w731 -->
# <g id="node2" class="node">
# <title>w731</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5391.23" cy="-3916.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w752 -->
# <g id="node156" class="node">
# <title>w752</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="5515.94" cy="-3988.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w731&#45;&#45;w752 -->
# <g id="edge1043" class="edge">
# <title>w731&#45;&#45;w752</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M5416.47,-3931.37C5438.1,-3943.86 5469.11,-3961.77 5490.74,-3974.25"/>
# </g>
# <!-- w1663 -->
# <g id="node3" class="node">
# <title>w1663</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11127.78" cy="-2044.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1664 -->
# <g id="node368" class="node">
# <title>w1664</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11127.78" cy="-2188.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1663&#45;&#45;w1664 -->
# <g id="edge1643" class="edge">
# <title>w1663&#45;&#45;w1664</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M11127.78,-2073.94C11127.78,-2098.92 11127.78,-2134.73 11127.78,-2159.7"/>
# </g>
# <!-- w318 -->
# <g id="node4" class="node">
# <title>w318</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3021.78" cy="-964.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w319 -->
# <g id="node208" class="node">
# <title>w319</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3021.78" cy="-1108.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w318&#45;&#45;w319 -->
# <g id="edge485" class="edge">
# <title>w318&#45;&#45;w319</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3021.78,-993.94C3021.78,-1018.92 3021.78,-1054.73 3021.78,-1079.7"/>
# </g>
# <!-- w339 -->
# <g id="node972" class="node">
# <title>w339</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="3146.49" cy="-892.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w318&#45;&#45;w339 -->
# <g id="edge483" class="edge">
# <title>w318&#45;&#45;w339</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M3047.02,-950.23C3068.66,-937.74 3099.67,-919.83 3121.29,-907.35"/>
# </g>
# <!-- w1085 -->
# <g id="node5" class="node">
# <title>w1085</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="7386.55" cy="-3484.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w870 -->
# <g id="node6" class="node">
# <title>w870</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="6264.18" cy="-2260.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w891 -->
# <g id="node772" class="node">
# <title>w891</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="6388.89" cy="-2188.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w870&#45;&#45;w891 -->
# <g id="edge96" class="edge">
# <title>w870&#45;&#45;w891</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M6289.42,-2246.23C6311.06,-2233.74 6342.07,-2215.83 6363.69,-2203.35"/>
# </g>
# <!-- w871 -->
# <g id="node1176" class="node">
# <title>w871</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="6264.18" cy="-2404.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w870&#45;&#45;w871 -->
# <g id="edge1642" class="edge">
# <title>w870&#45;&#45;w871</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M6264.18,-2289.94C6264.18,-2314.92 6264.18,-2350.73 6264.18,-2375.7"/>
# </g>
# <!-- w618 -->
# <g id="node7" class="node">
# <title>w618</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4767.69" cy="-2260.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w619 -->
# <g id="node1576" class="node">
# <title>w619</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4767.69" cy="-2404.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w618&#45;&#45;w619 -->
# <g id="edge739" class="edge">
# <title>w618&#45;&#45;w619</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4767.69,-2289.94C4767.69,-2314.92 4767.69,-2350.73 4767.69,-2375.7"/>
# </g>
# <!-- w1322 -->
# <g id="node8" class="node">
# <title>w1322</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="8883.04" cy="-316.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1343 -->
# <g id="node640" class="node">
# <title>w1343</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="9007.75" cy="-244.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1322&#45;&#45;w1343 -->
# <g id="edge28" class="edge">
# <title>w1322&#45;&#45;w1343</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M8908.28,-302.23C8929.92,-289.74 8960.93,-271.83 8982.55,-259.35"/>
# </g>
# <!-- w1323 -->
# <g id="node1208" class="node">
# <title>w1323</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="8883.04" cy="-460.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1322&#45;&#45;w1323 -->
# <g id="edge29" class="edge">
# <title>w1322&#45;&#45;w1323</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M8883.04,-345.94C8883.04,-370.92 8883.04,-406.73 8883.04,-431.7"/>
# </g>
# <!-- w1625 -->
# <g id="node9" class="node">
# <title>w1625</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10753.66" cy="-2260.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1639 -->
# <g id="node165" class="node">
# <title>w1639</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10878.37" cy="-2188.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1625&#45;&#45;w1639 -->
# <g id="edge306" class="edge">
# <title>w1625&#45;&#45;w1639</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M10778.9,-2246.23C10800.53,-2233.74 10831.54,-2215.83 10853.17,-2203.35"/>
# </g>
# <!-- w9 -->
# <g id="node10" class="node">
# <title>w9</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="402.92" cy="-28.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w526 -->
# <g id="node11" class="node">
# <title>w526</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4268.86" cy="-532.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w527 -->
# <g id="node22" class="node">
# <title>w527</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="4268.86" cy="-676.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w526&#45;&#45;w527 -->
# <g id="edge1207" class="edge">
# <title>w526&#45;&#45;w527</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M4268.86,-561.94C4268.86,-586.92 4268.86,-622.73 4268.86,-647.7"/>
# </g>
# <!-- w1697 -->
# <g id="node12" class="node">
# <title>w1697</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11501.9" cy="-2836.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1705 -->
# <g id="node1105" class="node">
# <title>w1705</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11626.61" cy="-2908.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1697&#45;&#45;w1705 -->
# <g id="edge907" class="edge">
# <title>w1697&#45;&#45;w1705</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M11527.14,-2851.37C11548.78,-2863.86 11579.79,-2881.77 11601.41,-2894.25"/>
# </g>
# <!-- w1637 -->
# <g id="node13" class="node">
# <title>w1637</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10878.37" cy="-1756.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1650 -->
# <g id="node1020" class="node">
# <title>w1650</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="11003.07" cy="-1828.8" rx="28.8" ry="28.8"/>
# </g>
# <!-- w1637&#45;&#45;w1650 -->
# <g id="edge1035" class="edge">
# <title>w1637&#45;&#45;w1650</title>
# <path fill="none" stroke="SteelBlue" stroke-width="32" d="M10903.6,-1771.37C10925.24,-1783.86 1

# %% [markdown]
# A grid of tiny labyrinths:

# %%
#%html
my @mazes = random-maze((5...7).pick) xx 36;
my @maze-plots = @mazes.map({ $_.dot(|merge-hash(%opts, {:1size, edge-thickness => 25}), :svg) });

(^@mazes.elems)
==> to-html(:multi-column, :6columns)
==> { .subst(/ '<td>' (\d+) '</td>' /, { '<td>' ~ @maze-plots[$0.Str.Int] }, :g) ~ '</td>'  }()
# Out:
# <table border="1"><tbody><tr><td><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.0.0 (20250921.2048)
#  -->
# <!-- Pages: 1 -->
# <svg width="72pt" height="72pt"
#  viewBox="0.00 0.00 72.00 72.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.2267 0.2267) rotate(0) translate(4 313.6)">
# <polygon fill="none" stroke="none" points="-4,4 -4,-313.6 313.6,-313.6 313.6,4 -4,4"/>
# <!-- w1_3 -->
# <g id="node1" class="node">
# <title>w1_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_3 -->
# <g id="node12" class="node">
# <title>w2_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_3&#45;&#45;w2_3 -->
# <g id="edge20" class="edge">
# <title>w1_3&#45;&#45;w2_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M226.8,-94.05C226.8,-107.66 226.8,-130.4 226.8,-143.86"/>
# </g>
# <!-- w1_4 -->
# <g id="node14" class="node">
# <title>w1_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_3&#45;&#45;w1_4 -->
# <g id="edge7" class="edge">
# <title>w1_3&#45;&#45;w1_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M238.05,-82.8C251.66,-82.8 274.4,-82.8 287.86,-82.8"/>
# </g>
# <!-- w2_2 -->
# <g id="node2" class="node">
# <title>w2_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_1 -->
# <g id="node3" class="node">
# <title>w4_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_2 -->
# <g id="node11" class="node">
# <title>w4_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_1&#45;&#45;w4_2 -->
# <g id="edge10" class="edge">
# <title>w4_1&#45;&#45;w4_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M94.05,-298.8C107.66,-298.8 130.4,-298.8 143.86,-298.8"/>
# </g>
# <!-- w1_0 -->
# <g id="node4" class="node">
# <title>w1_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_0 -->
# <g id="node17" class="node">
# <title>w2_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_0&#45;&#45;w2_0 -->
# <g id="edge12" class="edge">
# <title>w1_0&#45;&#45;w2_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M10.8,-94.05C10.8,-107.66 10.8,-130.4 10.8,-143.86"/>
# </g>
# <!-- w0_3 -->
# <g id="node5" class="node">
# <title>w0_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_4 -->
# <g id="node22" class="node">
# <title>w0_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_3&#45;&#45;w0_4 -->
# <g id="edge19" class="edge">
# <title>w0_3&#45;&#45;w0_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M238.05,-10.8C251.66,-10.8 274.4,-10.8 287.86,-10.8"/>
# </g>
# <!-- w3_4 -->
# <g id="node6" class="node">
# <title>w3_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_4 -->
# <g id="node7" class="node">
# <title>w2_4</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="298.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_4&#45;&#45;w3_4 -->
# <g id="edge18" class="edge">
# <title>w2_4&#45;&#45;w3_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M298.8,-166.05C298.8,-179.66 298.8,-202.4 298.8,-215.86"/>
# </g>
# <!-- w3_0 -->
# <g id="node8" class="node">
# <title>w3_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_0 -->
# <g id="node21" class="node">
# <title>w4_0</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="10.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_0&#45;&#45;w4_0 -->
# <g id="edge4" class="edge">
# <title>w3_0&#45;&#45;w4_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M10.8,-238.05C10.8,-251.66 10.8,-274.4 10.8,-287.86"/>
# </g>
# <!-- w1_1 -->
# <g id="node9" class="node">
# <title>w1_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_2 -->
# <g id="node15" class="node">
# <title>w1_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-82.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_1&#45;&#45;w1_2 -->
# <g id="edge13" class="edge">
# <title>w1_1&#45;&#45;w1_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M94.05,-82.8C107.66,-82.8 130.4,-82.8 143.86,-82.8"/>
# </g>
# <!-- w2_1 -->
# <g id="node19" class="node">
# <title>w2_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-154.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w1_1&#45;&#45;w2_1 -->
# <g id="edge14" class="edge">
# <title>w1_1&#45;&#45;w2_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M82.8,-94.05C82.8,-107.66 82.8,-130.4 82.8,-143.86"/>
# </g>
# <!-- w0_2 -->
# <g id="node10" class="node">
# <title>w0_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_2&#45;&#45;w0_3 -->
# <g id="edge1" class="edge">
# <title>w0_2&#45;&#45;w0_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M166.05,-10.8C179.66,-10.8 202.4,-10.8 215.86,-10.8"/>
# </g>
# <!-- w4_3 -->
# <g id="node18" class="node">
# <title>w4_3</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="226.8" cy="-298.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w4_2&#45;&#45;w4_3 -->
# <g id="edge15" class="edge">
# <title>w4_2&#45;&#45;w4_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M166.05,-298.8C179.66,-298.8 202.4,-298.8 215.86,-298.8"/>
# </g>
# <!-- w3_2 -->
# <g id="node13" class="node">
# <title>w3_2</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="154.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w3_2&#45;&#45;w4_2 -->
# <g id="edge16" class="edge">
# <title>w3_2&#45;&#45;w4_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M154.8,-238.05C154.8,-251.66 154.8,-274.4 154.8,-287.86"/>
# </g>
# <!-- w1_4&#45;&#45;w2_4 -->
# <g id="edge6" class="edge">
# <title>w1_4&#45;&#45;w2_4</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M298.8,-94.05C298.8,-107.66 298.8,-130.4 298.8,-143.86"/>
# </g>
# <!-- w1_2&#45;&#45;w1_3 -->
# <g id="edge17" class="edge">
# <title>w1_2&#45;&#45;w1_3</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M166.05,-82.8C179.66,-82.8 202.4,-82.8 215.86,-82.8"/>
# </g>
# <!-- w1_2&#45;&#45;w2_2 -->
# <g id="edge5" class="edge">
# <title>w1_2&#45;&#45;w2_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M154.8,-94.05C154.8,-107.66 154.8,-130.4 154.8,-143.86"/>
# </g>
# <!-- w3_1 -->
# <g id="node16" class="node">
# <title>w3_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-226.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w2_0&#45;&#45;w3_0 -->
# <g id="edge3" class="edge">
# <title>w2_0&#45;&#45;w3_0</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M10.8,-166.05C10.8,-179.66 10.8,-202.4 10.8,-215.86"/>
# </g>
# <!-- w2_1&#45;&#45;w3_1 -->
# <g id="edge21" class="edge">
# <title>w2_1&#45;&#45;w3_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M82.8,-166.05C82.8,-179.66 82.8,-202.4 82.8,-215.86"/>
# </g>
# <!-- w0_1 -->
# <g id="node20" class="node">
# <title>w0_1</title>
# <ellipse fill="SteelBlue" stroke="Black" cx="82.8" cy="-10.8" rx="10.8" ry="10.8"/>
# </g>
# <!-- w0_1&#45;&#45;w0_2 -->
# <g id="edge2" class="edge">
# <title>w0_1&#45;&#45;w0_2</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M94.05,-10.8C107.66,-10.8 130.4,-10.8 143.86,-10.8"/>
# </g>
# <!-- w4_0&#45;&#45;w4_1 -->
# <g id="edge11" class="edge">
# <title>w4_0&#45;&#45;w4_1</title>
# <path fill="none" stroke="SteelBlue" stroke-width="25" d="M22.05,-298.8C35.66,-298.8 58.4,-298.8 71.86,-298.8"/>
# </g>
# <!-- w0_4&#45;&#45;w1_4 -->
# <g id="edge8" class="edge">
# <title>

# %% [markdown]
# ---

# %% [markdown]
# ## References

# %% [markdown]
# ### Articles
#
# [AA1] Anton Antonov,
# ["Day 24 – Maze Making Using Graphs"](https://raku-advent.blog/2025/12/24/day-24-maze-making-using-graphs/),
# (2025),
# [Raku Advent Calendar at WordPress](https://raku-advent.blog/).
#
# ### Notebooks
#
# [AAn1] Anton Antonov,
# ["Maze making using graphs"](https://community.wolfram.com/groups/-/m/t/3597439),
# (2026),
# [Wolfram Community](https://community.wolfram.com).
#
# ### Packages
#
# [AAp1] Anton Antonov,
# [Graph::RandomMaze, Raku package](https://github.com/antononcube/Raku-Graph-RandomMaze),
# (2025),
# [GitHub/antononcube](https://github.com/antononcube).
#
# [AAp2] Anton Antonov,
# [Graph, Raku package](https://github.com/antononcube/Raku-Graph),
# (2024-2025),
# [GitHub/antononcube](https://github.com/antononcube).
